# %%
#Assignment 1 
import numpy as np
cluster1 = []
for i in range(100):
    cluster1.append([np.random.uniform(2,4),np.random.uniform(2,4)])
                     
cluster2 = []
for i in  range(100):
    cluster2.append([np.random.uniform(0,2),np.random.uniform(0,2)])
        
import matplotlib.pyplot as plt
plt.scatter([i[0] for i in cluster1],[i[1] for i in cluster1])
plt.scatter([i[0] for i in cluster2],[i[1] for i in cluster2])
mean1x = np.mean(cluster1[0])
mean1y = np.mean(cluster1[1])
mean2x = np.mean(cluster2[0])
mean2y = np.mean(cluster2[1])
mean2 = [sum(i[0] for i in cluster2)/100,sum(i[1] for i in cluster2)/100]
plt.scatter(mean1x,mean1y)
plt.scatter(mean2x,mean2y)

x,y = np.random.uniform(0,4),np.random.uniform(0,4)
plt.scatter(x,y)

dist1 = np.linalg.norm(mean1x-mean1y)
dist2 = np.linalg.norm(mean2x-mean2y)
if dist1<=dist2:
    print("BELONGS TO CLUSTER1")
else:
    print("BELONGS TO CLUSTER2")
# Out:
# BELONGS TO CLUSTER2
