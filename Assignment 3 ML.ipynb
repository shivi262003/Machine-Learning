# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\iris dataset')
dataset.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
new_columns_name = []
for i in range(1,len(dataset.columns[:4])+1):
    name = 'X'
    new_columns_name.append(name+str(i))
new_columns_name.append('Y')
dataset.columns = new_columns_name
print(dataset.columns)
dataset
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'Y'], dtype='object')
#       X1   X2   X3   X4          Y
# 0    5.1  3.5  1.4  0.2     Setosa
# 1    4.9  3.0  1.4  0.2     Setosa
# 2    4.7  3.2  1.3  0.2     Setosa
# 3    4.6  3.1  1.5  0.2     Setosa
# 4    5.0  3.6  1.4  0.2     Setosa
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  Virginica
# 146  6.3  2.5  5.0  1.9  Virginica
# 147  6.5  3.0  5.2  2.0  Virginica
# 148  6.2  3.4  5.4  2.3  Virginica
# 149  5.9  3.0  5.1  1.8  Virginica
#
# [150 rows x 5 columns]

# %%
dataset['Y'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
number = dataset['Y'].unique()
values = [i for i in range(len(number))]
mapp = dict(zip(number,values))
print(mapp)
# Out:
# {'Setosa': 0, 'Versicolor': 1, 'Virginica': 2}

# %%
dataset['Y'] = dataset['Y'].replace(number,values)
dataset
# Out:
#       X1   X2   X3   X4  Y
# 0    5.1  3.5  1.4  0.2  0
# 1    4.9  3.0  1.4  0.2  0
# 2    4.7  3.2  1.3  0.2  0
# 3    4.6  3.1  1.5  0.2  0
# 4    5.0  3.6  1.4  0.2  0
# ..   ...  ...  ...  ... ..
# 145  6.7  3.0  5.2  2.3  2
# 146  6.3  2.5  5.0  1.9  2
# 147  6.5  3.0  5.2  2.0  2
# 148  6.2  3.4  5.4  2.3  2
# 149  5.9  3.0  5.1  1.8  2
#
# [150 rows x 5 columns]

# %%
features = dataset.to_numpy()
print(features)
# Out:
# [[5.1 3.5 1.4 0.2 0. ]
#  [4.9 3.  1.4 0.2 0. ]
#  [4.7 3.2 1.3 0.2 0. ]
#  [4.6 3.1 1.5 0.2 0. ]
#  [5.  3.6 1.4 0.2 0. ]
#  [5.4 3.9 1.7 0.4 0. ]
#  [4.6 3.4 1.4 0.3 0. ]
#  [5.  3.4 1.5 0.2 0. ]
#  [4.4 2.9 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.1 0. ]
#  [5.4 3.7 1.5 0.2 0. ]
#  [4.8 3.4 1.6 0.2 0. ]
#  [4.8 3.  1.4 0.1 0. ]
#  [4.3 3.  1.1 0.1 0. ]
#  [5.8 4.  1.2 0.2 0. ]
#  [5.7 4.4 1.5 0.4 0. ]
#  [5.4 3.9 1.3 0.4 0. ]
#  [5.1 3.5 1.4 0.3 0. ]
#  [5.7 3.8 1.7 0.3 0. ]
#  [5.1 3.8 1.5 0.3 0. ]
#  [5.4 3.4 1.7 0.2 0. ]
#  [5.1 3.7 1.5 0.4 0. ]
#  [4.6 3.6 1.  0.2 0. ]
#  [5.1 3.3 1.7 0.5 0. ]
#  [4.8 3.4 1.9 0.2 0. ]
#  [5.  3.  1.6 0.2 0. ]
#  [5.  3.4 1.6 0.4 0. ]
#  [5.2 3.5 1.5 0.2 0. ]
#  [5.2 3.4 1.4 0.2 0. ]
#  [4.7 3.2 1.6 0.2 0. ]
#  [4.8 3.1 1.6 0.2 0. ]
#  [5.4 3.4 1.5 0.4 0. ]
#  [5.2 4.1 1.5 0.1 0. ]
#  [5.5 4.2 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.2 0. ]
#  [5.  3.2 1.2 0.2 0. ]
#  [5.5 3.5 1.3 0.2 0. ]
#  [4.9 3.6 1.4 0.1 0. ]
#  [4.4 3.  1.3 0.2 0. ]
#  [5.1 3.4 1.5 0.2 0. ]
# ...

# %%
clusters = {}
for name in mapp.keys():
    clusters[name]=features[np.where(features[:,4]==mapp[name])]
print(clusters)
# Out:
# {'Setosa': array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ],
#        [5.4, 3.9, 1.7, 0.4, 0. ],
#        [4.6, 3.4, 1.4, 0.3, 0. ],
#        [5. , 3.4, 1.5, 0.2, 0. ],
#        [4.4, 2.9, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [5.4, 3.7, 1.5, 0.2, 0. ],
#        [4.8, 3.4, 1.6, 0.2, 0. ],
#        [4.8, 3. , 1.4, 0.1, 0. ],
#        [4.3, 3. , 1.1, 0.1, 0. ],
#        [5.8, 4. , 1.2, 0.2, 0. ],
#        [5.7, 4.4, 1.5, 0.4, 0. ],
#        [5.4, 3.9, 1.3, 0.4, 0. ],
#        [5.1, 3.5, 1.4, 0.3, 0. ],
#        [5.7, 3.8, 1.7, 0.3, 0. ],
#        [5.1, 3.8, 1.5, 0.3, 0. ],
#        [5.4, 3.4, 1.7, 0.2, 0. ],
#        [5.1, 3.7, 1.5, 0.4, 0. ],
#        [4.6, 3.6, 1. , 0.2, 0. ],
#        [5.1, 3.3, 1.7, 0.5, 0. ],
#        [4.8, 3.4, 1.9, 0.2, 0. ],
#        [5. , 3. , 1.6, 0.2, 0. ],
#        [5. , 3.4, 1.6, 0.4, 0. ],
# ...

# %%
x = np.empty((0,5))
y = np.empty((0,5))
for class_ in clusters.keys():
    x = np.array(np.append(x,clusters[class_][:-10],axis=0))
    y = np.array(np.append(y,clusters[class_][:-10],axis=0))
training_dataset=x
testing_dataset=y

# %%
_class_ = {}
for name in mapp.keys():
    _class_[name]=training_dataset[np.where(training_dataset[:,4]==mapp[name])][:,:4]
_class_
# Out:
# {'Setosa': array([[5.1, 3.5, 1.4, 0.2],
#         [4.9, 3. , 1.4, 0.2],
#         [4.7, 3.2, 1.3, 0.2],
#         [4.6, 3.1, 1.5, 0.2],
#         [5. , 3.6, 1.4, 0.2],
#         [5.4, 3.9, 1.7, 0.4],
#         [4.6, 3.4, 1.4, 0.3],
#         [5. , 3.4, 1.5, 0.2],
#         [4.4, 2.9, 1.4, 0.2],
#         [4.9, 3.1, 1.5, 0.1],
#         [5.4, 3.7, 1.5, 0.2],
#         [4.8, 3.4, 1.6, 0.2],
#         [4.8, 3. , 1.4, 0.1],
#         [4.3, 3. , 1.1, 0.1],
#         [5.8, 4. , 1.2, 0.2],
#         [5.7, 4.4, 1.5, 0.4],
#         [5.4, 3.9, 1.3, 0.4],
#         [5.1, 3.5, 1.4, 0.3],
#         [5.7, 3.8, 1.7, 0.3],
#         [5.1, 3.8, 1.5, 0.3],
#         [5.4, 3.4, 1.7, 0.2],
#         [5.1, 3.7, 1.5, 0.4],
#         [4.6, 3.6, 1. , 0.2],
#         [5.1, 3.3, 1.7, 0.5],
#         [4.8, 3.4, 1.9, 0.2],
#         [5. , 3. , 1.6, 0.2],
#         [5. , 3.4, 1.6, 0.4],
#         [5.2, 3.5, 1.5, 0.2],
#         [5.2, 3.4, 1.4, 0.2],
#         [4.7, 3.2, 1.6, 0.2],
# ...

# %%
cluster_mean = dict(zip([f"mean{X}" for X in range(1,len(_class_.keys())+1)],[np.mean(_class_[name],axis=0) for name in _class_.keys()]))
cluster_mean
# Out:
# {'mean1': array([5.0375, 3.4525, 1.46  , 0.235 ]),
#  'mean2': array([6.01  , 2.78  , 4.3175, 1.35  ]),
#  'mean3': array([6.6225, 2.96  , 5.6075, 1.99  ])}

# %%
def testing(test_points):
    dist1=np.sqrt(np.sum(np.square(np.subtract(cluster_mean['mean1'],test_points))))
    dist2=np.sqrt(np.sum(np.square(np.subtract(cluster_mean['mean2'],test_points))))
    dist3=np.sqrt(np.sum(np.square(np.subtract(cluster_mean['mean3'],test_points))))
    if dist1<=dist2 and dist1<=dist3:
        cluster = 0
    elif dist2<=dist3 and dist2<=dist1:
        cluster = 1
    else:
        cluster = 2
    return cluster

# %%
correct = 0
incorrect = 0
for i in testing_dataset[:,:5]:
    count = 1
    test_points = i[:4]
    if testing(test_points)==i[4]:
        correct+=1
    else:
        incorrect+=1
print('correct result: ',correct,':incorrect result: ',incorrect)
accuracy = (correct/len(testing_dataset))*100
print('Accuracy is: ',accuracy)
# Out:
# correct result:  109 :incorrect result:  11
# Accuracy is:  90.83333333333333
